# %%
import phyflow as pf
import phyflow.monte_carlo as mc
import phyflow.phy_flow_matching as pfm
from pathlib import Path
import math
import torch
from pytorch_lightning import seed_everything
from torch._inductor import config
from torchvision.transforms.v2 import Compose, RandomHorizontalFlip, RandomVerticalFlip
from torch.utils.data import ConcatDataset, DataLoader
from torch.optim.lr_scheduler import OneCycleLR
import matplotlib.pyplot as plt
from scipy.stats import entropy
import numpy as np
import time
import logging

# %%
trash = []
seed_everything(3407, workers=True)
torch.set_float32_matmul_precision('high')
config.trace.log_autotuning_results = False
torch._logging.set_logs(inductor=logging.WARNING)
sympy_interp_logger = logging.getLogger("torch.utils._sympy.interp")
sympy_interp_logger.setLevel(logging.ERROR)
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
torch.cuda.empty_cache()
pf.get_complete_device_info()
# Out:
# 2025-08-10 13:55:39,699 - INFO - Seed set to 3407
# ========================================
#       Complete Device and Firmware Information
# ========================================
# Operating System: Linux 6.6.87.2-microsoft-standard-WSL2
# Architecture: x86_64
# CPU Model: x86_64
# CPU Full Model: AMD Ryzen 9 9950X 16-Core Processor
# PyTorch Version: 2.7.1+cu128
# CUDA Status: Available
# CUDA Version (used by PyTorch): 12.8
# Number of GPUs Available: 1
# --- GPU 0 ---
#   GPU Model: NVIDIA GeForce RTX 4080
#   Total Memory: 17.17 GB
#   Allocated Memory: 0.19 GB
#   Cached Memory (Reserved): 0.20 GB
# cuDNN Version: 90701
# ========================================

# %% [markdown]
# # Increase Sample Density Lab

# %% [markdown]
# ### Prepare the save path

# %%
save_root = './'
save_folder_name = 'FM_MC_distribution_analysis_log'
pf.create_directory(root_path=save_root, folder_name=save_folder_name)
fm_save_dir_root = Path(save_root) / save_folder_name
precision_0_01_path = 'precision_0_01'
pf.create_directory(root_path=fm_save_dir_root, folder_name=precision_0_01_path)
fm_save_dir_root_precision_0_01 = fm_save_dir_root / precision_0_01_path

# %% [markdown]
# ### Prepare the Monte Carlo data of the XY model

# %%
save_dir_root = './'
xy_generator = mc.MCDataGenerator(sampler_class=mc.XYModel, save_dir_root=save_dir_root)

L = 32
T_start = 0.1
T_end = 2.0
precision = 0.01
ensemble_number = 1500
# Out:
# 2025-08-10 13:55:39,934 - INFO - MCDataGenerator initialized for XYModel with save root: .

# %%
xy_generator.forward(
    L=L,
    T_start=T_start,
    T_end=T_end,
    precision=precision,
    ensemble_number=ensemble_number,
    device=device,
)
trash.append(xy_generator)
# Out:
# 2025-08-10 13:55:40,070 - INFO - --- Simulation Parameters for XYModel ---
# 2025-08-10 13:55:40,071 - INFO - Lattice size (L): 32
# 2025-08-10 13:55:40,071 - INFO - Temperature range: 0.1 to 2.0 (precision: 0.01, steps: 190)
# 2025-08-10 13:55:40,072 - INFO - Device: cuda:0
# 2025-08-10 13:55:40,072 - INFO - Ensemble number per T: 1500
# 2025-08-10 13:55:40,072 - INFO - Number of chains (n_chains): 10
# 2025-08-10 13:55:40,073 - INFO - Parallel Tempering: Enabled (interval: 1, prob: 0.1)
# 2025-08-10 13:55:40,073 - INFO - Calculated tau: 2048.0, tau_eff: 10.0
# 2025-08-10 13:55:40,073 - INFO - Thermalization sweeps (n_therm): 61440 (factor: 30)
# 2025-08-10 13:55:40,074 - INFO - Decorrelation sweeps (decorrelate): 19 (factor: 2)
# 2025-08-10 13:55:40,074 - INFO - Production sweeps (n_sweeps): 2850
# 2025-08-10 13:55:40,074 - INFO - -----------------------------------------------------
# 2025-08-10 13:55:40,079 - INFO - Starting Monte Carlo simulation...
# Initialized MonteCarloSampler on device: cuda:0
#  L=32, BatchSize=190, ChainsPerTemp=10, AMP=True, PT=True, LargeSim=False
# Starting simulation: 61440 thermalization sweeps, 2850 production sweeps.
# Thermalization phase...
# Production phase...
# Simulation finished. Collected 1500 samples.
# 2025-08-10 13:58:05,802 - INFO - Simulation finished. Elapsed time: 145.72 s
# 2025-08-10 13:58:05,803 - INFO - Generated samples shape: torch.Size([190, 1500, 32, 32])
# 2025-08-10 13:58:05,806 - INFO - Ensured directory exists: mc_data
# 2025-08-10 13:58:05,808 - INFO - Ensured directory exists: mc_data/XYModel
# 2025-08-10 13:58:05,811 - INFO - Ensured directory exists: mc_data/XYModel/field_config
# 2025-08-10 13:58:05,814 - INFO - Ensured directory exists: mc_data/XYModel/measurement
# 2025-08-10 13:58:05,815 - INFO - Saving field configurations to: mc_data/XYModel/field_config/XYModel_L32_T0_100-2_000_prec0_010_ens1500_configs.pt
# 2025-08-10 13:58:05,815 - INFO - Configs tensor shape: torch.Size([190, 1500, 32, 32])
# 2025-08-10 13:58:05,815 - INFO - Labels tensor shape: torch.Size([190, 2])
# labels shape: torch.Size([190, 2])
# first label pair: tensor([ 0.1000, 32.0000])
# 2025-08-10 13:58:11,404 - INFO - Field configurations saved.
# 2025-08-10 13:58:11,405 - INFO - Performing measurements...
# 2025-08-10 13:58:14,691 - INFO - Measurements complete.
# 2025-08-10 13:58:14,691 - INFO - Saving measurements dictionary to: mc_data/XYModel/measurement/XYModel_L32_T0_100-2_000_prec0_010_ens1500_measurements.pt
# 2025-08-10 13:58:14,695 - INFO - Measurements dictionary saved.
# 2025-08-10 13:58:14,695 - INFO - Saving plots to: mc_data/XYModel/measurement/XYModel_L32_T0_100-2_000_prec0_010_ens1500_plots.png
# 2025-08-10 13:58:15,190 - INFO - Plots saved.
# 2025-08-10 13:58:15,793 - INFO - Cleared CUDA cache.
# 2025-08-10 13:58:15,794 - INFO - MCDataGenerator call finished. Total time: 155.72 s

# %%
save_dir_root = Path(save_dir_root)
sampler_name = mc.XYModel.__name__
mc_data_dir = save_dir_root / "mc_data"
sampler_dir = mc_data_dir / sampler_name
field_config_dir = sampler_dir / "field_config"
filename_base = f"{sampler_name}_L{L}_T{T_start:.3f}-{T_end:.3f}_prec{precision:.3f}_ens{ensemble_number}"
filename_base = filename_base.replace('.', '_')
config_save_path = field_config_dir / f"{filename_base}_configs.pt"

mc_config_results = torch.load(config_save_path, map_location='cpu', weights_only=False)

measurement_dir = sampler_dir / "measurement"
measurement_save_path_pt = measurement_dir / f"{filename_base}_measurements.pt"

mc_measure_results = torch.load(measurement_save_path_pt, map_location='cpu', weights_only=False)

measurement_save_path_png = measurement_dir / f"{filename_base}_plots.png"
img = pf.load_image_pil(measurement_save_path_png)

pf.display_image_pil(img, figsize=(12, 12))

# %%
xy_spin_config_0_01 = mc_config_results['configs']
labels_0_01 = mc_config_results['labels']
T = torch.linspace(T_start, T_end, int((T_end - T_start) // precision) + 1, device=device)

xy_spin_config_0_01.shape
# Out:
# torch.Size([190, 1500, 32, 32])

# %%
trash.append(mc_config_results)
pf.clear_cuda_cache(trash)
trash = []

# %% [markdown]
# ### Prepare the neural network

# %%
num_conditions = 1

model_parameter_dict = {
    'in_channels': 1,
    'out_channels': 1,
    'model_channels': 32,
    'downsample_out_ch_mult': (1, 1, 2,),
    'start_attn_level': 2,
    'num_blocks': 1,
    'dropout': 0.2,
    'num_heads': 4,
    'num_conditions': num_conditions,
    'emb_dim': 32,
    'padding_mode': 'circular',
}

model_0_01 = pfm.FlowUNet(**model_parameter_dict).to(device)

dummy_inputs = {
    'x': torch.randn(32, 1, L, L, device="cuda"),
    'time': torch.randn(32, device="cuda"),
    'conditions': [torch.randn(32, device="cuda") for _ in range(num_conditions)]
}

pf.profile_model(model_0_01, dummy_inputs)
# Out:
# Parameters:                           214.65 K
# FLOPs (floating point operations):    0.9776 G
# Estimated memory usage (params only): 0.82 MB

# %%
# from torch.profiler import profile, record_function, ProfilerActivity
#
# optimizer = torch.optim.AdamW(model.parameters(), lr=2e-4, weight_decay=0.1)
#
# with profile(activities=[ProfilerActivity.CPU, ProfilerActivity.CUDA], record_shapes=True) as prof:
#     with record_function("model_forward"):
#         outputs = model(**dummy_inputs)
#     with record_function("loss_backward"):
#         loss = outputs.sum()
#         loss.backward()
#     with record_function("optimizer_step"):
#         optimizer.step()
#
# print(prof.key_averages().table(sort_by="cuda_time_total", row_limit=10))
#
# prof.export_chrome_trace("trace.json")

# %% [markdown]
# #### Model Architecture

# %%
pf.check_model(model_0_01)
# Out:
# FlowUNet(
#   (time_embedder): SinusoidalPosEmb()
#   (time_mlp_embedders): MLPEmbedder(
#     (mlp_emb_in_layer): Linear(in_features=32, out_features=128, bias=True)
#     (mlp_emb_act): SiLU()
#     (mlp_emb_out_layer): Linear(in_features=128, out_features=32, bias=True)
#   )
#   (cond_pos_embedders): ModuleList(
#     (0): SinusoidalPosEmb()
#   )
#   (cond_mlp_embedders): ModuleList(
#     (0): MLPEmbedder(
#       (mlp_emb_in_layer): Linear(in_features=32, out_features=128, bias=True)
#       (mlp_emb_act): SiLU()
#       (mlp_emb_out_layer): Linear(in_features=128, out_features=32, bias=True)
#     )
#   )
#   (mlp_msa): ConditionalMSAWithRoPE(
#     (norm): RMSNorm((32,), eps=1e-06, elementwise_affine=True)
#     (seq_expand_proj): Linear(in_features=2, out_features=32, bias=True)
#     (qkv_projection): Linear(in_features=32, out_features=96, bias=False)
#     (rope): RoPE()
#     (seq_combine_proj): Linear(in_features=32, out_features=1, bias=False)
#   )
#   (conv_in): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=circular)
#   (down_blocks): ModuleList(
#     (0-1): 2 x ModuleList(
#       (0): ResnetBlock(
#         (norm1): RMSNorm2d()
#         (attn_or_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, padding_mode=circular)
#         (norm2): RMSNorm2d()
#         (mlp): Mlp(
#           (pw_conv1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): GELU(approximate='tanh')
#           (drop1): Dropout(p=0.2, inplace=False)
#           (pw_conv2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (adaLN_modulation): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=32, out_features=192, bias=True)
#         )
#       )
#     )
#   )
#   (down_samplers): ModuleList(
#     (0): ConditionalDownsample(
#       (dw_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, padding_mode=circular)
#       (channel_proj): ConditionalChannelProjection(
#         (norm): RMSNorm2d()
#         (adaLN_modulation): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=32, out_features=64, bias=True)
#         )
#         (conv): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#         (act): SELU()
#       )
#       (pixel_shuffle): PixelUnshuffle(downscale_factor=2)
#     )
#     (1): ConditionalDownsample(
#       (dw_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, padding_mode=circular)
#       (channel_proj): ConditionalChannelProjection(
#         (norm): RMSNorm2d()
#         (adaLN_modulation): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=32, out_features=64, bias=True)
#         )
#         (conv): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1))
#         (act): SELU()
#       )
#       (pixel_shuffle): PixelUnshuffle(downscale_factor=2)
#     )
#   )
#   (middle_blocks): ModuleList(
#     (0-1): 2 x ResnetBlock(
#       (norm1): RMSNorm2d()
#       (attn_or_conv): MSAWithRoPE(
#         (qkv_projection): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=64, bias=False, padding_mode=circular)
#         (q_norm): RMSNorm((16,), eps=1e-06, elementwise_affine=True)
#         (k_norm): RMSNorm((16,), eps=1e-06, elementwise_affine=True)
#         (rope): RoPEMixed()
#       )
#       (norm2): RMSNorm2d()
#       (mlp): Mlp(
#         (pw_conv1): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1))
#         (act): GELU(approximate='tanh')
#         (drop1): Dropout(p=0.2, inplace=False)
#         (pw_conv2): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (adaLN_modulation): Sequential(
#         (0): SiLU()
#         (1): Linear(in_features=32, out_features=384, bias=True)
#       )
#     )
#   )
#   (up_blocks): ModuleList(
#     (0-1): 2 x ModuleList(
#       (0): ResnetBlock(
#         (norm1): RMSNorm2d()
#         (attn_or_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, padding_mode=circular)
#         (norm2): RMSNorm2d()
#         (mlp): Mlp(
#           (pw_conv1): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#           (act): GELU(approximate='tanh')
#           (drop1): Dropout(p=0.2, inplace=False)
#           (pw_conv2): Conv2d(128, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (adaLN_modulation): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=32, out_features=192, bias=True)
#         )
#       )
#     )
#   )
#   (up_samplers): ModuleList(
#     (0): ConditionalUpsample(
#       (channel_proj): ConditionalChannelProjection(
#         (norm): RMSNorm2d()
#         (adaLN_modulation): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=32, out_features=128, bias=True)
#         )
#         (conv): Conv2d(64, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SELU()
#       )
#       (pixel_shuffle): PixelShuffle(upscale_factor=2)
#       (act): SiLU()
#     )
#     (1): ConditionalUpsample(
#       (channel_proj): ConditionalChannelProjection(
#         (norm): RMSNorm2d()
#         (adaLN_modulation): Sequential(
#           (0): SiLU()
#           (1): Linear(in_features=32, out_features=64, bias=True)
#         )
#         (conv): Conv2d(32, 128, kernel_size=(1, 1), stride=(1, 1))
#         (act): SELU()
#       )
#       (pixel_shuffle): PixelShuffle(upscale_factor=2)
#       (act): SiLU()
#     )
#   )
#   (up_proj_convs): ModuleList(
#     (0-1): 2 x Sequential(
#       (0): RMSNorm2d()
#       (1): Conv2d(32, 32, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (skip_norm): ModuleList(
#     (0-1): 2 x Sequential(
#       (0): RMSNorm2d()
#     )
#   )
#   (final_layer): FinalLayer(
#     (norm): RMSNorm2d()
#     (adaLN_modulation): Sequential(
#       (0): Linear(in_features=32, out_features=128, bias=True)
#       (1): SiLU()
#       (2): Linear(in_features=128, out_features=64, bias=True)
#     )
#     (act): SELU()
#     (conv_out): Conv2d(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=circular)
#   )
# )
# Total number of trainable parameters: 0.21 M

# %% [markdown]
# ### Prepare the dataset

# %%
t_focus_start_1 = 0.0
t_focus_end_1 = 1.38
t_focus_start_index_1 = len(T[T <= t_focus_start_1])
t_focus_end_index_1 = len(T[T <= t_focus_end_1])

# %%
labels_selected_0_01 = labels_0_01[:, 0]

transform_1 = Compose([
    pfm.RandomGlobalRotation(),
    pfm.RandomRoll(max_shift=(L//2, L//2), p=1.0),
    RandomHorizontalFlip(p=0.5),
    pfm.RandomRoll(max_shift=(L//2, L//2), p=1.0),
    pfm.RandomGlobalRotation(),
    RandomVerticalFlip(p=0.5),
    pfm.RandomRoll(max_shift=(L//2, L//2), p=1.0),
    pfm.RandomGlobalRotation(),
    pfm.RandomRoll(max_shift=(L//2, L//2), p=1.0),
])

xy_dataset_raw = mc.MCDataset(
    data=xy_spin_config_0_01,
    labels=labels_selected_0_01,
)

xy_dataset_transform_1 = mc.MCDataset(
    data=xy_spin_config_0_01,
    labels=labels_selected_0_01,
    transform=transform_1,
)

xy_spin_config_0_01_focus = xy_spin_config_0_01[t_focus_start_index_1:t_focus_end_index_1, ...]
labels_selected_0_01_focus = labels_selected_0_01[t_focus_start_index_1:t_focus_end_index_1, ...]

reps = math.ceil(xy_spin_config_0_01.shape[0] / xy_spin_config_0_01_focus.shape[0])
repeated_config_focus = xy_spin_config_0_01_focus.repeat(reps,1,1,1)[:xy_spin_config_0_01.shape[0], ...]
repeated_labels_focus = labels_selected_0_01_focus.repeat(reps)[:xy_spin_config_0_01.shape[0], ...]

xy_dataset_focus_1_transform_1 = mc.MCDataset(
    data=repeated_config_focus,
    labels=repeated_labels_focus,
    transform=transform_1,
)

xy_dataset = ConcatDataset([
    xy_dataset_raw,
    xy_dataset_transform_1,
    xy_dataset_focus_1_transform_1
])

batch_size = 32
batch_size_mod = pf.find_closest_factor(len(xy_dataset), batch_size)
print(f"Optimal batch size: {batch_size_mod}")

xy_dataloader = DataLoader(xy_dataset, batch_size=batch_size_mod,shuffle=True)
# Out:
# Optimal batch size: 30

# %%
def random_global_rotate(x: torch.Tensor) -> torch.Tensor:
    """Apply a random global rotation (phase shift) to each 2-D field in a batch.

    The same random scalar θ ∈ [0, 2π) is added to **all** spatial positions
    in each sample.  After the shift, the result is wrapped into the range
    `[0, 2π)` with a modulo operation.

    Args:
        x (torch.Tensor): Input tensor of shape **(B, 1, H, W)** and any
            floating‐point dtype.

    Returns:
        torch.Tensor: Tensor with the same shape, dtype, and device as `x`,
        where for every *b* in `0 … B-1`

        ```text
        y[b, 0, :, :] = (x[b, 0, :, :] + θ_b) mod 2π.
        ```

    Notes:
        * The function is fully differentiable.
        * If `x` requires gradients, the returned tensor will as well.

    """
    if x.ndim != 4 or x.size(1) != 1:
        raise ValueError(
            f"Expected input of shape (B, 1, H, W); got {tuple(x.shape)}"
        )

    # Draw B independent scalars θ_b ∈ [0, 2π) with the same dtype/device as `x`.
    theta: torch.Tensor = torch.rand(
        x.size(0), 1, 1, 1, dtype=x.dtype, device=x.device
    ) * (2 * torch.pi)

    # Add and wrap into [0, 2π).
    y: torch.Tensor = torch.fmod(x + theta, 2 * torch.pi)

    # return (y - torch.pi) / torch.pi  # Shift to [-1, 1] range for better training stability.
    return y

# %% [markdown]
# ### Prepare the flow matching executor

# %%
gradient_accumulation_steps = 4
base_lr = gradient_accumulation_steps * 3e-4
total_epochs = 10

# init optimizer
optimizer = torch.optim.AdamW(model_0_01.parameters(), lr=base_lr, weight_decay=0.1)

scheduler = OneCycleLR(
    optimizer=optimizer,
    max_lr=base_lr,
    total_steps=total_epochs+1,
    pct_start=1/3
)

fmex_0_01 = pfm.CFMExecutor(
    save_dir_root=fm_save_dir_root_precision_0_01,
    model_params=model_parameter_dict,
    model=model_0_01,
    model_wrapper=pfm.CFMWrapper,
    optimizer=optimizer,
    lr_scheduler=scheduler,
    device=device,
)
# Out:
# 2025-08-10 13:58:22,071 - INFO - Save directory root 'FM_MC_distribution_analysis_log/precision_0_01' confirmed/created.
# 2025-08-10 13:58:22,073 - INFO - AutoClip initialized with percentile=10.0, window_size=1000.
# 2025-08-10 13:58:22,074 - INFO - CFMExecutor initialized. Device: cuda:0
# 2025-08-10 13:58:22,074 - INFO - Save directory root: FM_MC_distribution_analysis_log/precision_0_01
# 2025-08-10 13:58:22,075 - WARNING - Base distribution p0 not provided. Likelihood computation will default to standard Normal or may not be available if data shape is incompatible.

# %% [markdown]
# ### Train the model

# %%
fmex_0_01.train(
    train_loaders=(
        xy_dataloader,
    ),
    num_epochs=total_epochs,
    save_every_epochs=10,
    gradient_accumulation_steps=gradient_accumulation_steps,
    mu_logit=0.0,
    sigma_logit = 1.0,
    data_argumentation_fn=random_global_rotate
)
# Out:
# 2025-08-10 13:58:22,202 - INFO - Total batches per epoch from all loaders: 28500
# 2025-08-10 13:58:22,203 - INFO - Effective batch size (approx, based on first loader): 120
# 2025-08-10 13:58:22,203 - INFO - Starting training for 10 epochs.
# 2025-08-10 13:58:22,204 - INFO - Gradient Accumulation Steps: 4
# 2025-08-10 13:58:22,205 - INFO - Using logit-normal sampler with mu_logit=0.0000, sigma_logit=1.0000. This controls the sampling distribution for time t.
# 2025-08-10 14:04:49,790 - INFO - Epoch 1/10 completed in 387.58s.
# 2025-08-10 14:04:49,791 - INFO -   Average Epoch Loss: 2.3051
# 2025-08-10 14:04:49,791 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:04:49,792 - INFO -   Last AutoClip threshold used: 2.6152
# 2025-08-10 14:04:49,792 - INFO -   LR scheduler stepped. New LR: 0.000404
# 2025-08-10 14:04:49,793 - INFO - ------------------------------------------------------------
# 2025-08-10 14:04:49,794 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:11:12,526 - INFO - Epoch 2/10 completed in 382.73s.
# 2025-08-10 14:11:12,527 - INFO -   Average Epoch Loss: 1.6710
# 2025-08-10 14:11:12,527 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:11:12,528 - INFO -   Last AutoClip threshold used: 1.6727
# 2025-08-10 14:11:12,529 - INFO -   LR scheduler stepped. New LR: 0.001031
# 2025-08-10 14:11:12,529 - INFO - ------------------------------------------------------------
# 2025-08-10 14:11:12,530 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:17:38,249 - INFO - Epoch 3/10 completed in 385.72s.
# 2025-08-10 14:17:38,249 - INFO -   Average Epoch Loss: 1.6617
# 2025-08-10 14:17:38,250 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:17:38,250 - INFO -   Last AutoClip threshold used: 1.6280
# 2025-08-10 14:17:38,250 - INFO -   LR scheduler stepped. New LR: 0.001194
# 2025-08-10 14:17:38,251 - INFO - ------------------------------------------------------------
# 2025-08-10 14:17:38,252 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:24:03,209 - INFO - Epoch 4/10 completed in 384.96s.
# 2025-08-10 14:24:03,209 - INFO -   Average Epoch Loss: 1.6556
# 2025-08-10 14:24:03,210 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:24:03,210 - INFO -   Last AutoClip threshold used: 1.8879
# 2025-08-10 14:24:03,211 - INFO -   LR scheduler stepped. New LR: 0.001105
# 2025-08-10 14:24:03,211 - INFO - ------------------------------------------------------------
# 2025-08-10 14:24:03,212 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:30:28,474 - INFO - Epoch 5/10 completed in 385.26s.
# 2025-08-10 14:30:28,475 - INFO -   Average Epoch Loss: 1.6507
# 2025-08-10 14:30:28,475 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:30:28,475 - INFO -   Last AutoClip threshold used: 2.1603
# 2025-08-10 14:30:28,476 - INFO -   LR scheduler stepped. New LR: 0.000924
# 2025-08-10 14:30:28,477 - INFO - ------------------------------------------------------------
# 2025-08-10 14:30:28,478 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:36:52,988 - INFO - Epoch 6/10 completed in 384.51s.
# 2025-08-10 14:36:52,988 - INFO -   Average Epoch Loss: 1.6463
# 2025-08-10 14:36:52,989 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:36:52,990 - INFO -   Last AutoClip threshold used: 1.9022
# 2025-08-10 14:36:52,991 - INFO -   LR scheduler stepped. New LR: 0.000685
# 2025-08-10 14:36:52,991 - INFO - ------------------------------------------------------------
# 2025-08-10 14:36:52,992 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:43:20,664 - INFO - Epoch 7/10 completed in 387.67s.
# 2025-08-10 14:43:20,665 - INFO -   Average Epoch Loss: 1.6423
# 2025-08-10 14:43:20,665 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:43:20,666 - INFO -   Last AutoClip threshold used: 1.9233
# 2025-08-10 14:43:20,667 - INFO -   LR scheduler stepped. New LR: 0.000431
# 2025-08-10 14:43:20,667 - INFO - ------------------------------------------------------------
# 2025-08-10 14:43:20,668 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:49:50,106 - INFO - Epoch 8/10 completed in 389.44s.
# 2025-08-10 14:49:50,107 - INFO -   Average Epoch Loss: 1.6401
# 2025-08-10 14:49:50,108 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:49:50,109 - INFO -   Last AutoClip threshold used: 1.9375
# 2025-08-10 14:49:50,111 - INFO -   LR scheduler stepped. New LR: 0.000207
# 2025-08-10 14:49:50,111 - INFO - ------------------------------------------------------------
# 2025-08-10 14:49:50,113 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 14:56:19,188 - INFO - Epoch 9/10 completed in 389.08s.
# 2025-08-10 14:56:19,189 - INFO -   Average Epoch Loss: 1.6337
# 2025-08-10 14:56:19,190 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 14:56:19,191 - INFO -   Last AutoClip threshold used: 1.6573
# 2025-08-10 14:56:19,193 - INFO -   LR scheduler stepped. New LR: 0.000054
# 2025-08-10 14:56:19,194 - INFO - ------------------------------------------------------------
# 2025-08-10 14:56:19,195 - INFO - Keeping sigma_logit = 1.0000 for this epoch.
# 2025-08-10 15:02:49,453 - INFO - Epoch 10/10 completed in 390.26s.
# 2025-08-10 15:02:49,455 - INFO -   Average Epoch Loss: 1.6327
# 2025-08-10 15:02:49,456 - INFO -   Optimizer steps in epoch: 7125
# 2025-08-10 15:02:49,458 - INFO -   Last AutoClip threshold used: 1.4439
# 2025-08-10 15:02:49,459 - INFO -   LR scheduler stepped. New LR: 0.000000
# 2025-08-10 15:02:49,517 - INFO - Checkpoint saved successfully to FM_MC_distribution_analysis_log/precision_0_01/checkpoints/checkpoint_epoch_0010.pth (Epoch 10)
# 2025-08-10 15:02:49,518 - INFO - ------------------------------------------------------------
# 2025-08-10 15:02:49,520 - INFO - Training finished.
# 2025-08-10 15:02:49,587 - INFO - Training loss plot saved to: FM_MC_distribution_analysis_log/precision_0_01/training_loss_plot.png

# %% [markdown]
# ### Sample with the trained model

# %% [markdown]
# #### Sample with 5 step

# %%
fmex_0_01.load_checkpoint(fm_save_dir_root_precision_0_01/f'checkpoints/checkpoint_epoch_{total_epochs:04d}.pth')

L = 32
Temp_start = 0.1
Temp_end = 2.0
precision = 0.01
num_samples = 1500
num_steps = 5
timestep_schedule_mu = -0.3
timestep_schedule_sigma = 1.0

num_temp = int((Temp_end-Temp_start)//precision)+1 
print(f'num_temp: {num_temp}')

B_opt = pf.estimate_max_batch_size(
    model = model_0_01,
    num_data=num_temp * num_samples,
    channels=1,
    height=L,
    width=L,
    time_steps=num_steps,
    num_conditions=num_conditions,
    num_evals=3,
    device=device,
    use_adjoint=False,
    safety_factor=0.9
)
print(f"Optimal batch size: {B_opt}")
B_opt_mod = pf.find_closest_factor(num_temp * num_samples, B_opt)
print(f"Optimal batch size (modify): {B_opt_mod}")

Temp = torch.linspace(Temp_start, Temp_end, steps=num_temp)
x_init = torch.randn((num_temp, num_samples, L, L), dtype=torch.float32)

xy_inference_dataset = mc.MCDataset(data=x_init, labels=Temp)
xy_inference_dataloader = DataLoader(xy_inference_dataset, batch_size=B_opt_mod, shuffle=False)

torch.cuda.empty_cache()
torch.cuda.synchronize(device)

_ = fmex_0_01.solve(
    solve_loader=xy_inference_dataloader,
    num_samples=num_samples,
    num_steps=10,
    for_gpu_warmup=True,
)

sol_time_start = time.time()
sol = fmex_0_01.solve(
    solve_loader=xy_inference_dataloader,
    num_samples=num_samples,
    num_steps=num_steps,
    method='heun3',
    timestep_schedule_mu=timestep_schedule_mu,
    timestep_schedule_sigma=timestep_schedule_sigma,
)
sol_time_end = time.time()
torch.cuda.empty_cache()
print(f'Solving time for L={L}: {sol_time_end - sol_time_start:.2f} seconds')
# Out:
# 2025-08-10 15:02:49,788 - INFO - Loaded AutoClip gradient history from checkpoint.
# 2025-08-10 15:02:49,789 - INFO - Loaded checkpoint from FM_MC_distribution_analysis_log/precision_0_01/checkpoints/checkpoint_epoch_0010.pth. Last completed epoch: 10.
# 2025-08-10 15:02:49,789 - INFO - Training will resume from epoch 11.
# 2025-08-10 15:02:49,790 - INFO -   Last recorded average epoch loss: 1.6327
# 2025-08-10 15:02:49,790 - INFO -   Associated model params from checkpoint: {'in_channels': 1, 'out_channels': 1, 'model_channels': 32, 'downsample_out_ch_mult': (1, 1, 2), 'start_attn_level': 2, 'num_blocks': 1, 'dropout': 0.2, 'num_heads': 4, 'num_conditions': 1, 'emb_dim': 32, 'padding_mode': 'circular'}
# num_temp: 190
# Optimal batch size: 620
# Optimal batch size (modify): 625
# 2025-08-10 15:02:51,774 - INFO - Using the original model's velocity field (via wrapper) for sampling.
# 2025-08-10 15:02:51,774 - INFO - Performing GPU warmup. No actual sampling will be done.
# 2025-08-10 15:02:51,775 - INFO - Starting sample generation (solving ODE)...
# 2025-08-10 15:02:51,775 - INFO -   Solver: heun3, Time Grid (Original): [0.0, 1.0]
# 2025-08-10 15:02:51,776 - INFO -   Time Grid (Fixed Steps): [0.0, 0.10000000149011612, 0.20000000298023224, 0.30000001192092896, 0.4000000059604645, 0.5, 0.6000000238418579, 0.699999988079071, 0.800000011920929, 0.8999999761581421, 1.0]
# 2025-08-10 15:02:51,777 - INFO -   Time Grid (Scheduled for ODE): [0.0, 0.10000000149011612, 0.20000000298023224, 0.30000001192092896, 0.4000000059604645, 0.5, 0.6000000238418579, 0.699999988079071, 0.800000011920929, 0.8999999761581421, 1.0]
# 2025-08-10 15:02:52,560 - INFO - GPU warmup completed. Returning empty tensor.
# 2025-08-10 15:02:52,567 - INFO - Using the original model's velocity field (via wrapper) for sampling.
# 2025-08-10 15:02:52,567 - INFO - Starting sample generation (solving ODE)...
# 2025-08-10 15:02:52,568 - INFO -   Solver: heun3, Time Grid (Original): [0.0, 1.0]
# 2025-08-10 15:02:52,569 - INFO -   Time Grid (Fixed Steps): [0.0, 0.20000000298023224, 0.4000000059604645, 0.6000000238418579, 0.800000011920929, 1.0]
# 2025-08-10 15:02:52,570 - INFO -   Time Grid (Scheduled for ODE): [0.0, 0.1562637984752655, 0.33060163259506226, 0.5263419151306152, 0.7476832866668701, 1.0]
# 2025-08-10 15:05:18,030 - INFO - Reshaped generated solutions tensor shape: torch.Size([190, 1500, 32, 32])
# 2025-08-10 15:05:18,030 - INFO - Sample generation finished. Total samples: 285000.
# Solving time for L=32: 145.51 seconds

# %%
sampler_xy = mc.XYModel(
    L=L,
    T=Temp,
    device=torch.device(device),
    use_amp=True
)

# sampler_xy.spins = sol * torch.pi + torch.pi  # Shift to [0, 2π) range for sampling.
sampler_xy.spins = sol
trash.append(sol)
# Out:
# Initialized MonteCarloSampler on device: cuda:0
#  L=32, BatchSize=190, ChainsPerTemp=30, AMP=True, PT=True, LargeSim=False

# %%
fm_energy_0_01 = sampler_xy.plot_energy(
    plot_t_bkt=True,
    plot_first_derivative_peak=True,
    return_observation=True
)
fm_magnetization_0_01 = sampler_xy.plot_magnetization(
    plot_t_bkt=True,
    plot_first_derivative_peak=True,
    return_observation=True
)
fm_susceptibility_0_01 = sampler_xy.plot_susceptibility(
    plot_t_bkt=True,
    plot_peak_line=True,
    return_observation=True
)
fm_stiffness_0_01 = sampler_xy.plot_stiffness(
    plot_t_bkt=True,
    plot_first_derivative_peak=True,
    return_observation=True
)
fm_vortex_density_0_01 = sampler_xy.plot_vortex_density(
    plot_t_bkt=True,
    low_memory=True,
    return_observation=True
)

fm_energy_0_01_ensemble = sampler_xy.compute_energy()

# %% [markdown]
# ### Compare the results between flow matching and Monte Carlo

# %%
mc_temperature_0_01 = mc_measure_results['temperature']
mc_energy_0_01 = mc_measure_results['energy']
mc_specific_heat_0_01 = mc_measure_results['specific_heat']
mc_magnetization_0_01 = mc_measure_results['magnetization']
mc_susceptibility_0_01 = mc_measure_results['susceptibility']
mc_stiffness_0_01 = mc_measure_results['spin_stiffness']
mc_vortex_density_0_01 = mc_measure_results['vortex_density']

L = 32

sampler_xy = mc.XYModel(
    L=L,
    T=torch.tensor(mc_temperature_0_01),
    device=torch.device(device),
    use_amp=True
)

sampler_xy.spins = xy_spin_config_0_01
mc_energy_0_01_ensemble = sampler_xy.compute_energy()
# Out:
# Initialized MonteCarloSampler on device: cuda:0
#  L=32, BatchSize=190, ChainsPerTemp=30, AMP=True, PT=True, LargeSim=False

# %%
plt.style.use('seaborn-v0_8-pastel')

mc_color = "#2ED1FF"
fm_color = '#C23DFF'

Temp_0_01 = Temp.cpu()

fig, ax = plt.subplots(1, 3, figsize=(16, 4))
ax[0].scatter(mc_temperature_0_01, mc_energy_0_01, marker='D', label='MC', color=mc_color, alpha=0.8)
ax[0].scatter(Temp_0_01, fm_energy_0_01, marker='x', label='FM', color=fm_color, alpha=0.5)
ax[0].set_ylabel('Energy (E)', fontsize=16)
# ax[0].set_title('Energy', fontsize=16)

ax[1].scatter(mc_temperature_0_01, mc_magnetization_0_01, marker='D', label='MC', color=mc_color, alpha=0.8)
ax[1].scatter(Temp_0_01, fm_magnetization_0_01, marker='x', label='FM', color=fm_color, alpha=0.5)
ax[1].set_ylabel('Magnetization (M)', fontsize=16)
# ax[1].set_title('Magnetization', fontsize=16)

ax[2].scatter(mc_temperature_0_01, mc_susceptibility_0_01, marker='D', label='MC', color=mc_color, alpha=0.8)
ax[2].scatter(Temp_0_01, fm_susceptibility_0_01, marker='x', label='FM', color=fm_color, alpha=0.5)
peak_chi_idx = fm_susceptibility_0_01.argmax()
ax[2].axvline(Temp_0_01[peak_chi_idx], color='#FFA3A1', linestyle='--',
               label=f'$T_{{p}}={Temp_0_01[peak_chi_idx]:.2f}$')
ax[2].set_ylabel(r'Susceptibility ($\chi$)', fontsize=16)
# ax[2].set_title('Susceptibility', fontsize=16)

for i in range(3):
    ax[i].set_xlabel('Temperature (T)', fontsize=16)
    ax[i].legend(
        prop={'weight': 'bold', 'size': 16},
        labelcolor=[mc_color, fm_color, 'r'],
        markerscale=1.5,
        frameon=False
    )
plt.tight_layout()
plt.show()

# %%
plt.clf()
plt.style.use('seaborn-v0_8-pastel')

mc_stiffness_color = "#2ED1FF"
fm_stiffness_color = '#C23DFF' 

mc_vortex_density_color = "#FFCB00"
fm_vortex_density_color = "#FF4300"

stiffness_axis_color= "#936BFF"
vortex_axis_color = '#FF7400'


fig, ax1 = plt.subplots(figsize=(6, 5))
ax1.scatter(mc_temperature_0_01, mc_stiffness_0_01, marker='D', label='MC', color=mc_stiffness_color, alpha=0.8)
ax1.scatter(Temp_0_01, fm_stiffness_0_01, marker='x', label='FM', color=fm_stiffness_color, alpha=0.5)
ax1.set_xlabel('Temperature', fontsize=16)
ax1.set_ylabel(r'$\rho_s$', fontsize=16, color=stiffness_axis_color)
# ax1.set_ylabel(r'Spin Stiffness ($\rho_s$)', fontsize=16, color=stiffness_axis_color)
ax1.set_title(r'Spin Stiffness ($\rho_s$)', fontsize=16, color=stiffness_axis_color, loc='left')
ax1.tick_params(axis='y', labelsize=16, labelcolor=stiffness_axis_color)

ax1.legend(
    loc='center left',
    prop={'weight': 'bold', 'size': 16},
    labelcolor=[mc_stiffness_color, fm_stiffness_color],
    markerscale=1.5,
    frameon=False
)

ax2 = ax1.twinx()
ax2.scatter(mc_temperature_0_01, mc_vortex_density_0_01, marker='D', label='MC', color=mc_vortex_density_color, alpha=0.8)
ax2.scatter(Temp_0_01, fm_vortex_density_0_01, marker='x', label='FM', color=fm_vortex_density_color, alpha=0.5)
ax2.set_ylabel(r'$\rho_v$', fontsize=16, color=vortex_axis_color)
# ax2.set_ylabel(r'Vortex Density ($\rho_v$)', fontsize=16, color=vortex_axis_color)
ax2.set_title(r'Vortex Density ($\rho_v$)', fontsize=16, color=vortex_axis_color, loc='right')
ax2.tick_params(axis='y', labelsize=16, labelcolor=vortex_axis_color)

ax2.legend(
    loc='center right',
    prop={'weight': 'bold', 'size': 16},
    labelcolor=[mc_vortex_density_color, fm_vortex_density_color],
    markerscale=1.5,
    frameon=False
)

plt.show()

# %%
def mse_mae_estimator(fm_data_list, mc_data_list):
    """
    Calculate the MSE and MAE between flow matching and Monte Carlo data.

    Args:
        fm_data_list (list): List of flow matching data tensors.
        mc_data_list (list): List of Monte Carlo data tensors.

    Returns:
        tuple: MSE and MAE values.
    """
    mse_list = []
    mae_list = []

    for fm_data, mc_data in zip(fm_data_list, mc_data_list):
        fm_tensor = torch.tensor(fm_data)
        mc_tensor = torch.tensor(mc_data)

        mse = torch.nn.functional.mse_loss(fm_tensor, mc_tensor)
        mae = torch.nn.functional.l1_loss(fm_tensor, mc_tensor)

        mse_list.append(mse.item())
        mae_list.append(mae.item())

    return mse_list, mae_list

# %%
fm_results_list = [
    fm_energy_0_01,
    fm_magnetization_0_01,
    fm_susceptibility_0_01,
    fm_stiffness_0_01,
    fm_vortex_density_0_01,
]
mc_results_list = [
    mc_energy_0_01,
    mc_magnetization_0_01,
    mc_susceptibility_0_01,
    mc_stiffness_0_01,
    mc_vortex_density_0_01,
]

mse_list, mae_list = mse_mae_estimator(fm_results_list, mc_results_list)

print(f" Average MSE: {sum(mse_list) / len(mse_list)} ")
print(f" Average MAE: {sum(mae_list) / len(mae_list)} ")
# Out:
#  Average MSE: 0.365275301211409
#  Average MAE: 0.14848491894081234

# %%
trash.append(sampler_xy)
trash.append(xy_spin_config_0_01)
pf.clear_cuda_cache(trash)
trash = []

# %%
mc_energy_0_01_ensemble.shape
# Out:
# torch.Size([190, 1500])

# %%
mc_energy_0_01_ensemble.size().numel()
# Out:
# 285000

# %%
mc_max_energy = torch.max(mc_energy_0_01_ensemble)
mc_min_energy = torch.min(mc_energy_0_01_ensemble)
fm_max_energy = torch.max(fm_energy_0_01_ensemble)
fm_min_energy = torch.min(fm_energy_0_01_ensemble)

max_energy = max([fm_max_energy, mc_max_energy]).cpu().item()
min_energy = min([fm_min_energy, mc_min_energy]).cpu().item()

print(f" Max Energy: {max_energy}")
print(f" Min Energy: {min_energy}")
# Out:
#  Max Energy: -431.8240051269531
#  Min Energy: -2003.2694091796875

# %%
js_divergences = []
bins = np.linspace(min_energy, max_energy, int(np.sqrt(mc_energy_0_01_ensemble.size().numel())))

for t_idx in range(len(mc_temperature_0_01)):
    energy_mc_ = mc_energy_0_01_ensemble[t_idx, ...].cpu().numpy()
    energy_fm_ = fm_energy_0_01_ensemble[t_idx, ...].cpu().numpy()

    p, _ = np.histogram(energy_mc_, bins=bins, density=True)
    q, _ = np.histogram(energy_fm_, bins=bins, density=True)
    if p.sum() > 0: p /= p.sum()
    if q.sum() > 0: q /= q.sum()
    p += 1e-10; q += 1e-10
    m = 0.5 * (p + q)
    js_div = 0.5 * (entropy(pk=p, qk=m) + entropy(pk=q, qk=m))
    js_divergences.append(js_div)

fig, ax = plt.subplots(figsize=(12, 10))
ln_2 = np.log(2)
ax.axhline(y=ln_2, color='red', linestyle='--', linewidth=2, label=f'JSD Max: ln(2) ≈ {ln_2:.3f}')

ax.plot(mc_temperature_0_01, js_divergences, 'o-', color='teal', label='JS Divergence')

# ax.set_title('JS Divergence of energy distribution between FM & MC', fontsize=16)
ax.set_xlabel('Temperature (T)', fontsize=18)
ax.set_ylabel('JS Divergence', fontsize=18)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
ax.legend(bbox_to_anchor=(1.0, 0.93), fontsize=18,frameon=False,)
ax.grid(True, which='both', linestyle='--', linewidth=0.5)
ax.set_ylim(bottom=0,)

temps_to_plot = [0.1, 0.2, 1.0, 2.0]
indices_to_plot = [np.abs(mc_temperature_0_01 - t).argmin() for t in temps_to_plot]
inset_positions = [[0.03, 0.60, 0.25, 0.25],
                   [0.22, 0.25, 0.25, 0.25],
                   [0.55, 0.45, 0.25, 0.25],
                   [0.72, 0.10, 0.25, 0.25]]

for i, t_idx in enumerate(indices_to_plot):
    temp_val = mc_temperature_0_01[t_idx]
    pos = inset_positions[i]

    ax_inset = ax.inset_axes(pos)

    energy_mc_ = mc_energy_0_01_ensemble[t_idx, ...].cpu().numpy()
    energy_fm_ = fm_energy_0_01_ensemble[t_idx, ...].cpu().numpy()

    all_data = np.concatenate([energy_mc_.ravel(), energy_fm_.ravel()])

    global_min = all_data.min()
    global_max = all_data.max()

    ax_inset.hist(energy_mc_, bins=bins, density=True,
                  alpha=0.7, color='dodgerblue', label='MC')
    ax_inset.hist(energy_fm_, bins=bins, density=True,
                  alpha=0.7, color='coral', label='FM')

    ax_inset.set_yticklabels([])
    ax_inset.tick_params(axis='y', length=0)
    if i == 0 or i == 1:
        ax_inset.set_xlim(global_min-10, global_max+60)
        ax_inset.legend(frameon=False,fontsize=16)
    else:
        ax_inset.set_xlim(global_min, global_max)

    xy = (temp_val, js_divergences[t_idx])
    xytext = (pos[0] + pos[2]/2, pos[1] + pos[3])

    ax.annotate(f'T={temp_val:.1f}', xy=xy,
                xycoords='data',
                xytext=xytext,
                textcoords=ax.transAxes,
                arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=-0.2", color="gray"),
                ha='center', va='bottom',
                fontsize=16, bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="gray", lw=1, alpha=0.8))

plt.show()

# %%
plt.style.use('seaborn-v0_8-pastel')

mc_color = "#2ED1FF"
fm_color = '#C23DFF'

Temp_0_01 = Temp.cpu()

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].scatter(mc_temperature_0_01, mc_energy_0_01, marker='D', label='MC', color=mc_color, alpha=0.8)
ax[0].scatter(Temp_0_01, fm_energy_0_01, marker='x', label='FM', color=fm_color, alpha=0.5)
ax[0].set_ylabel('Energy (E)', fontsize=16)
# ax[0].set_title('Energy', fontsize=16)

fm_specific_heat_0_01 = torch.var(fm_energy_0_01_ensemble, dim=-1).squeeze().cpu().numpy() / (L * Temp_0_01) ** 2

ax[1].scatter(mc_temperature_0_01, mc_specific_heat_0_01, marker='D', label='MC', color=mc_color, alpha=0.8)
ax[1].scatter(Temp_0_01, fm_specific_heat_0_01, marker='x', label='FM', color=fm_color, alpha=0.5)
ax[1].set_ylabel('Specific Heat Capacity ($C_V$)', fontsize=16)
# peak_cv_idx = fm_specific_heat_0_01[50:].argmax()
# ax[1].axvline(Temp_0_01[50:][peak_cv_idx], color='#FFA3A1', linestyle='--',
#                label=f'$T_{{p}}={Temp_0_01[50:][peak_cv_idx]:.2f}$')
# ax[1].set_title('Specific Heat Capacity', fontsize=16)

for i in range(2):
    ax[i].set_xlabel('Temperature (T)', fontsize=16)
    ax[i].legend(
        prop={'weight': 'bold', 'size': 16},
        labelcolor=[mc_color, fm_color, 'r'],
        markerscale=1.5,
        frameon=False
    )
plt.tight_layout()
plt.show()
